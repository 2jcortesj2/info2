# %% [markdown]
# <p align="center"><img alt="udeA logo" height="150px" src="https://github.com/freddyduitama/images/blob/master/logo.png?raw=true"></p><h1><font color='0B5345'> <center>
#
# Probabilidad y estadística
#
#  </center></font></h1>
# <h2><font color='0B5345'> <center>
# Tercer Proyecto: Aprendizaje Supervisado</center></font></h2>
# <font  face="Courier New" size="3">
#
# <p3><center><b><font color='0B5345' face="Lucida Calligraphy,Comic Sans MS,Lucida Console" size="5">Universidad de Antioquia - Bioingeniería</font></b> </center></p3>

# %% [markdown]
# Carga de los archivos

# %%
import pandas as pd
import numpy as np

from scipy import stats

# %%
df_state = pd.read_csv('datos_state.csv', sep= ';')
df_state
# Out:
#     Population  Income  Illiteracy  Life_Exp  Murder  HS_Grad  Frost    Area  \
# 0         3615    3624         2.1     69.05    15.1     41.3     20   50708
# 1          365    6315         1.5     69.31    11.3     66.7    152  566432
# 2         2212    4530         1.8     70.55     7.8     58.1     15  113417
# 3         2110    3378         1.9     70.66    10.1     39.9     65   51945
# 4        21198    5114         1.1     71.71    10.3     62.6     20  156361
# 5         2541    4884         0.7     72.06     6.8     63.9    166  103766
# 6         3100    5348         1.1     72.48     3.1     56.0    139    4862
# 7          579    4809         0.9     70.06     6.2     54.6    103    1982
# 8         8277    4815         1.3     70.66    10.7     52.6     11   54090
# 9         4931    4091         2.0     68.54    13.9     40.6     60   58073
# 10         868    4963         1.9     73.60     6.2     61.9      0    6425
# 11         813    4119         0.6     71.87     5.3     59.5    126   82677
# 12       11197    5107         0.9     70.14    10.3     52.6    127   55748
# 13        5313    4458         0.7     70.88     7.1     52.9    122   36097
# 14        2861    4628         0.5     72.56     2.3     59.0    140   55941
# 15        2280    4669         0.6     72.58     4.5     59.9    114   81787
# 16        3387    3712         1.6     70.10    10.6     38.5     95   39650
# 17        3806    3545         2.8     68.76    13.2     42.2     12   44930
# 18        1058    3694         0.7     70.39     2.7     54.7    161   30920
# 19        4122    5299         0.9     70.22     8.5     52.3    101    9891
# 20        5814    4755         1.1     71.83     3.3     58.5    103    7826
# 21        9111    4751         0.9     70.63    11.1     52.8    125   56817
# 22        3921    4675         0.6     72.96     2.3     57.6    160   79289
# 23        2341    3098         2.4     68.09    12.5     41.0     50   47296
# 24        4767    4254         0.8     70.69     9.3     48.8    108   68995
# 25         746    4347         0.6     70.56     5.0     59.2    155  145587
# 26        1544    4508         0.6     72.60     2.9     59.3    139   76483
# 27         590    5149         0.5     69.03    11.5     65.2    188  109889
# 28         812    4281         0.7     71.23     3.3     57.6    174    9027
# 29        7333    5237         1.1     70.93     5.2     52.5    115    7521
# 30        1144    3601         2.2     70.32     9.7     55.2    120  121412
# 31       18076    4903         1.4     70.55    10.9     52.7     82   47831
# 32        5441    3875         1.8     69.21    11.1     38.5     80   48798
# 33         637    5087         0.8     72.78     1.4     50.3    186   69273
# 34       10735    4561         0.8     70.82     7.4     53.2    124   40975
# 35        2715    3983         1.1     71.42     6.4     51.6     82   68782
# 36        2284    4660         0.6     72.13     4.2     60.0     44   96184
# 37       11860    4449         1.0     70.43     6.1     50.2    126   44966
# 38         931    4558         1.3     71.90     2.4     46.4    127    1049
# 39        2816    3635         2.3     67.96    11.6     37.8     65   30225
# 40         681    4167         0.5     72.08     1.7     53.3    172   75955
# 41        4173    3821         1.7     70.11    11.0     41.8     70   41328
# 42       12237    4188         2.2     70.90    12.2     47.4     35  262134
# 43        1203    4022         0.6     72.90     4.5     67.3    137   82096
# 44         472    3907         0.6     71.64     5.5     57.1    168    9267
# 45        4981    4701         1.4     70.08     9.5     47.8     85   39780
# 46        3559    4864         0.6     71.72     4.3     63.5     32   66570
# 47        1799    3617         1.4     69.48     6.7     41.6    100   24070
# 48        4589    4468         0.7     72.48     3.0     54.5    149   54464
# 49         376    4566         0.6     70.29     6.9     62.9    173   97203
#
#     Density_pob
# 0     71.290526
# 1      0.644384
# 2     19.503249
# 3     40.619886
# 4    135.570890
# 5     24.487790
# 6    637.597696
# 7    292.129163
# 8    153.022740
# 9     84.910371
# 10   135.097276
# 11     9.833448
# 12   200.850255
# 13   147.186747
# 14    51.143169
# 15    27.877291
# 16    85.422446
# 17    84.709548
# 18    34.217335
# 19   416.742493
# 20   742.908254
# 21   160.356935
# 22    49.452005
# 23    49.496786
# 24    69.091963
# 25     5.124084
# 26    20.187493
# 27     5.369054
# 28    89.952365
# 29   975.003324
# 30     9.422462
# 31   377.913905
# 32   111.500471
# 33     9.195502
# 34   261.989018
# 35    39.472536
# 36    23.746153
# 37   263.754837
# 38   887.511916
# 39    93.167907
# 40     8.965835
# 41   100.972706
# 42    46.682231
# 43    14.653576
# 44    50.933420
# 45   125.213675
# 46    53.462521
# 47    74.740341
# 48    84.257491
# 49     3.868193

# %% [markdown]
# **Pruebas de normalidad y Homegeneidad**

# %%
def normalidad(data, columna):
    alfa = 0.05
    stat, p_value = stats.shapiro(data[columna])
    if p_value > alfa: # Distribucion normal
        return True 
    else:
        return False # No normal

# %%
def varianza(data, *args):
    alfa = 0.05
    stat, p_value = stats.levene(*args)
    if p_value > alfa:
        return True # Varianzas iguales
    else:
        return False # Varianzas diferentes

# %%
# Varianza
valor = varianza(df_state, df_state['Population'], df_state['Income'], 
                df_state['Illiteracy'], df_state['Life_Exp'], df_state['Murder'], 
                df_state['HS_Grad'], df_state['Frost'], df_state['Area'], df_state['Density_pob'])
print(f'Presenta homogeneidad de varianza: {valor}')

# Normalidad
for columna in df_state:
    print( f"La columna: {columna}\t presenta normaliadad: {normalidad(df_state, columna)} " )
# Out:
# Presenta homogeneidad de varianza: False
# La columna: Population	 presenta normaliadad: False
# La columna: Income	 presenta normaliadad: True
# La columna: Illiteracy	 presenta normaliadad: False
# La columna: Life_Exp	 presenta normaliadad: True
# La columna: Murder	 presenta normaliadad: False
# La columna: HS_Grad	 presenta normaliadad: False
# La columna: Frost	 presenta normaliadad: True
# La columna: Area	 presenta normaliadad: False
# La columna: Density_pob	 presenta normaliadad: False
